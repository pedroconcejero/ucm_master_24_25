# %% [markdown]
# # Master BigData UCM 2024_25

# %% [markdown]
# ## 1. Datos COVID

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import plotnine
from plotnine import *

# %% [markdown]
# ### Carga de datos
#
# A partir del fichero ya guardado en disco de su lectura y primer pre-proceso

# %%
covid = pd.read_pickle("datos_covid.pkl")

# %%
covid.shape
# Out:
# (1299030, 8)

# %%
covid.describe(include = 'all')
# Out:
#        provincia_iso     sexo grupo_edad                          fecha  \
# count        1274520  1299030    1299030                        1299030
# unique            52        3         10                            NaN
# top                A        H        0-9                            NaN
# freq           24510   433010     129903                            NaN
# mean             NaN      NaN        NaN  2021-02-12 00:00:00.000000256
# min              NaN      NaN        NaN            2020-01-01 00:00:00
# 25%              NaN      NaN        NaN            2020-07-23 00:00:00
# 50%              NaN      NaN        NaN            2021-02-12 00:00:00
# 75%              NaN      NaN        NaN            2021-09-04 00:00:00
# max              NaN      NaN        NaN            2022-03-27 00:00:00
# std              NaN      NaN        NaN                            NaN
#
#            num_casos      num_hosp       num_uci       num_def
# count   1.299030e+06  1.299030e+06  1.299030e+06  1.299030e+06
# unique           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN
# mean    8.916302e+00  4.002325e-01  3.814539e-02  7.993349e-02
# min     0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%     0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 50%     0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 75%     4.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# max     3.749000e+03  2.710000e+02  3.500000e+01  1.000000e+02
# std     5.078917e+01  2.523791e+00  3.111515e-01  8.045517e-01

# %% [markdown]
# # 2. Visualizaciones con ggplot
#
# Además del contenido recogido en la docu. teórica, es aconsejable seguir este excelente (y práctico) tutorial:
#
# https://realpython.com/ggplot-python/

# %% [markdown]
# ## 2.1 Barplot por sexo y edad

# %%
covid2 = covid.groupby(['sexo', 'grupo_edad']).sum(numeric_only = True)
covid2 = pd.DataFrame(covid2.to_records())

# %%
covid2
# Out:
#    sexo grupo_edad  num_casos  num_hosp  num_uci  num_def
# 0     H        0-9     551068      3356      177       15
# 1     H      10-19     763040      2375      192       15
# 2     H      20-29     772202      6641      527       78
# 3     H      30-39     808200     14199     1392      209
# 4     H      40-49     969947     31562     3690      749
# 5     H      50-59     705194     46558     7072     2746
# 6     H      60-69     417976     55989    10651     7444
# 7     H      70-79     262040     57114     8495    14781
# 8     H        80+     197154     65760     1409    31312
# 9     H         NC       1965       130        9       19
# 10    M        0-9     519666      2591      130        9
# 11    M      10-19     771120      2621      120       12
# 12    M      20-29     863197      8806      361       61
# 13    M      30-39     965945     16152      956      140
# 14    M      40-49    1131344     20921     1557      419
# 15    M      50-59     796494     29699     2911     1269
# 16    M      60-69     451393     35410     4622     3055
# 17    M      70-79     288410     40764     4026     7452
# 18    M        80+     335391     76670     1027    33793
# 19    M         NC       1764       109        5        9
# 20   NC        0-9        167         9        1        0
# 21   NC      10-19        153        16        1        0
# 22   NC      20-29        326        43        0        0
# 23   NC      30-39        332        85        2        1
# 24   NC      40-49        392       113        2        1
# 25   NC      50-59        419       160        9        1
# 26   NC      60-69        291       156       12        5
# 27   NC      70-79        244       167       14       16
# 28   NC        80+        558       392       32       46
# 29   NC         NC       6152      1346      150      179

# %%
mascara_sexo = covid2['sexo'] != 'NC'
mascara_grupo_edad = covid2['grupo_edad'] != 'NC'
covid2 = covid2[mascara_sexo]
covid2 = covid2[mascara_grupo_edad]
# Out:
# /tmp/ipykernel_81419/1743903409.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
covid2
# Out:
#    sexo grupo_edad  num_casos  num_hosp  num_uci  num_def
# 0     H        0-9     551068      3356      177       15
# 1     H      10-19     763040      2375      192       15
# 2     H      20-29     772202      6641      527       78
# 3     H      30-39     808200     14199     1392      209
# 4     H      40-49     969947     31562     3690      749
# 5     H      50-59     705194     46558     7072     2746
# 6     H      60-69     417976     55989    10651     7444
# 7     H      70-79     262040     57114     8495    14781
# 8     H        80+     197154     65760     1409    31312
# 10    M        0-9     519666      2591      130        9
# 11    M      10-19     771120      2621      120       12
# 12    M      20-29     863197      8806      361       61
# 13    M      30-39     965945     16152      956      140
# 14    M      40-49    1131344     20921     1557      419
# 15    M      50-59     796494     29699     2911     1269
# 16    M      60-69     451393     35410     4622     3055
# 17    M      70-79     288410     40764     4026     7452
# 18    M        80+     335391     76670     1027    33793

# %%
(
ggplot(covid2)
+ aes(x = 'grupo_edad',
      y = 'num_def')
    + geom_bar(stat = 'identity')
)

# %%
(
ggplot(covid2)
+ aes(x = 'grupo_edad',
      y = 'num_uci')
    + geom_bar(stat = "identity")
)

# %%
(
    ggplot(covid2)  # What data to use
    + aes('grupo_edad', 
          'num_hosp',
          fill = 'sexo')  # What variable to use
    + geom_bar(stat = "identity",
              position = 'dodge') # Geometric object to use for drawing
   
)

# %%
(
    ggplot(covid2)  # What data to use
    + aes('grupo_edad', 
          'num_casos',
          fill = 'sexo')  # What variable to use
    + geom_bar(stat = "identity",
              position = 'dodge') # Geometric object to use for drawing
   
)

# %%
grafico = (
    ggplot(covid2)  # What data to use
    + aes('grupo_edad', 
          'num_casos',
          fill = 'sexo')  # What variable to use
    + geom_bar(stat = "identity",
              position = 'dodge') # Geometric object to use for drawing
   
)

# %%
grafico2 = grafico + ( coord_flip())

# %%
grafico2

# %%
(
    ggplot(covid2)  # What data to use
    + aes('grupo_edad', 
          'num_uci',
          fill = 'sexo')  # What variable to use
    + geom_bar(stat = "identity",
              position = 'dodge') # Geometric object to use for drawing
    + coord_flip()
    + scale_fill_manual(values = ("blue", "pink"))
)

# %%
(
    ggplot(covid2)  # What data to use
    + aes('grupo_edad', 
          'num_uci',
          fill = 'sexo')  # What variable to use
    + geom_bar(position = "dodge",
               stat = "identity")
    + coord_flip()# Geometric object to use for drawing
   
)

# %%
(
    ggplot(covid2)  # What data to use
    + aes('grupo_edad', 
          'num_def',
          fill = 'sexo')  # What variable to use
    + geom_bar(position = "dodge",
               stat = "identity") # Geometric object to use for drawing
    + coord_flip()
    + scale_fill_manual(values = ("blue", "pink"))
   
)

# %%
(
    ggplot(covid2)  # What data to use
    + aes('grupo_edad', 
          'num_def',
          fill = 'sexo')  # What variable to use
    + geom_bar(position = "dodge",
               stat = "identity")
#    + scale_y_log10()# Geometric object to use for drawing
   
)

# %% [markdown]
# ## 2.2 Olas (series temporales)

# %%
covid3 = covid.groupby(['sexo', 'fecha']).sum(numeric_only=True)
covid3 = pd.DataFrame(covid3.to_records())
mascara_sexo = covid3['sexo'] != 'NC'
#mascara_grupo_edad = covid3['grupo_edad'] != 'NC'
covid3 = covid3[mascara_sexo]
#covid2 = covid3[mascara_grupo_edad]

# %%
covid3.head()
# Out:
#   sexo      fecha  num_casos  num_hosp  num_uci  num_def
# 0    H 2020-01-01          0         5        0        0
# 1    H 2020-01-02          0        43        1        0
# 2    H 2020-01-03          0         2        0        0
# 3    H 2020-01-04          0         2        0        0
# 4    H 2020-01-05          0         3        0        0

# %%
g = (
    ggplot(covid3)  # What data to use
    + aes(x = "fecha", 
          y = "num_casos")  # What variable to use
    + geom_line() 
    + theme(axis_text_x = element_text(angle = 45, 
                                       hjust = 1,
                                       size = 10))# Geometric object to use for drawing
)

# %%
g = g + theme(figure_size=(12, 12))

# %%
g

# %%
g = (
    ggplot(covid3)  # What data to use
    + aes(x = "fecha", 
          y = "num_casos",
         color = 'sexo')  # What variable to use
    + geom_smooth(method = "lowess"
                  ,span = 0.05
                 )  # Geometric object to use for drawing
)

# %%
g = g + theme(figure_size=(12, 12))

# %%
g
# Out:
# /home/pedro/Escritorio/UCM_2024/entorno_octubre/lib/python3.12/site-packages/plotnine/stats/smoothers.py:347: PlotnineWarning: Confidence intervals are not yet implemented for lowess smoothings.
# /home/pedro/Escritorio/UCM_2024/entorno_octubre/lib/python3.12/site-packages/plotnine/stats/smoothers.py:347: PlotnineWarning: Confidence intervals are not yet implemented for lowess smoothings.

# %%
g = g + theme(figure_size=(12, 10))

# %%
g
# Out:
# /home/pedro/Escritorio/UCM_2024/entorno_octubre/lib/python3.12/site-packages/plotnine/stats/smoothers.py:347: PlotnineWarning: Confidence intervals are not yet implemented for lowess smoothings.
# /home/pedro/Escritorio/UCM_2024/entorno_octubre/lib/python3.12/site-packages/plotnine/stats/smoothers.py:347: PlotnineWarning: Confidence intervals are not yet implemented for lowess smoothings.

# %%
g.save('olas01.png', dpi=600)
# Out:
# /home/pedro/Escritorio/UCM_2024/entorno_octubre/lib/python3.12/site-packages/plotnine/ggplot.py:606: PlotnineWarning: Saving 12 x 10 in image.
# /home/pedro/Escritorio/UCM_2024/entorno_octubre/lib/python3.12/site-packages/plotnine/ggplot.py:607: PlotnineWarning: Filename: olas01.png
# /home/pedro/Escritorio/UCM_2024/entorno_octubre/lib/python3.12/site-packages/plotnine/stats/smoothers.py:347: PlotnineWarning: Confidence intervals are not yet implemented for lowess smoothings.
# /home/pedro/Escritorio/UCM_2024/entorno_octubre/lib/python3.12/site-packages/plotnine/stats/smoothers.py:347: PlotnineWarning: Confidence intervals are not yet implemented for lowess smoothings.

# %%
g + theme(axis_text_x = element_text(angle = -45, 
                                     vjust = 1))
# Out:
# /home/pedro/Escritorio/UCM_2024/entorno_octubre/lib/python3.12/site-packages/plotnine/stats/smoothers.py:347: PlotnineWarning: Confidence intervals are not yet implemented for lowess smoothings.
# /home/pedro/Escritorio/UCM_2024/entorno_octubre/lib/python3.12/site-packages/plotnine/stats/smoothers.py:347: PlotnineWarning: Confidence intervals are not yet implemented for lowess smoothings.

# %%
(
    ggplot(covid3)  # What data to use
    + aes(x = "fecha", 
          y = "num_casos",
          color = 'sexo')  # What variable to use
    + geom_line()  # Geometric object to use for drawing
)

# %%
(
    ggplot(covid3)  # What data to use
    + aes(x = "fecha", 
          y = "num_casos",
          color = 'sexo')  # What variable to use
    + geom_smooth(method = "lowess", 
                  span = 0.05)  # Geometric object to use for drawing
)
# Out:
# /home/pedro/Escritorio/UCM_2024/entorno_octubre/lib/python3.12/site-packages/plotnine/stats/smoothers.py:347: PlotnineWarning: Confidence intervals are not yet implemented for lowess smoothings.
# /home/pedro/Escritorio/UCM_2024/entorno_octubre/lib/python3.12/site-packages/plotnine/stats/smoothers.py:347: PlotnineWarning: Confidence intervals are not yet implemented for lowess smoothings.

# %%
(
    ggplot(covid3)  # What data to use
    + aes(x = "fecha", 
          y = "num_uci",
          color = 'sexo')  # What variable to use
    + geom_smooth(method = "lowess", 
                  span = 0.05)  # Geometric object to use for drawing
)
# Out:
# /home/pedro/Escritorio/UCM_2024/entorno_octubre/lib/python3.12/site-packages/plotnine/stats/smoothers.py:347: PlotnineWarning: Confidence intervals are not yet implemented for lowess smoothings.
# /home/pedro/Escritorio/UCM_2024/entorno_octubre/lib/python3.12/site-packages/plotnine/stats/smoothers.py:347: PlotnineWarning: Confidence intervals are not yet implemented for lowess smoothings.
