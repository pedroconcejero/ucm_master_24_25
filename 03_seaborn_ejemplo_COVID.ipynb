# %% [markdown]
# # Master BigData UCM 2024_25

# %% [markdown]
# ## 1. Datos COVID

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Carga de datos
#
# A partir del fichero ya guardado en disco de su lectura y primer pre-proceso

# %%
covid = pd.read_pickle("datos_covid.pkl")

# %%
covid.shape
# Out:
# (1299030, 8)

# %%
covid.describe(include = 'all')
# Out:
#        provincia_iso     sexo grupo_edad                          fecha  \
# count        1274520  1299030    1299030                        1299030
# unique            52        3         10                            NaN
# top                A        H        0-9                            NaN
# freq           24510   433010     129903                            NaN
# mean             NaN      NaN        NaN  2021-02-12 00:00:00.000000256
# min              NaN      NaN        NaN            2020-01-01 00:00:00
# 25%              NaN      NaN        NaN            2020-07-23 00:00:00
# 50%              NaN      NaN        NaN            2021-02-12 00:00:00
# 75%              NaN      NaN        NaN            2021-09-04 00:00:00
# max              NaN      NaN        NaN            2022-03-27 00:00:00
# std              NaN      NaN        NaN                            NaN
#
#            num_casos      num_hosp       num_uci       num_def
# count   1.299030e+06  1.299030e+06  1.299030e+06  1.299030e+06
# unique           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN
# mean    8.916302e+00  4.002325e-01  3.814539e-02  7.993349e-02
# min     0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%     0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 50%     0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 75%     4.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# max     3.749000e+03  2.710000e+02  3.500000e+01  1.000000e+02
# std     5.078917e+01  2.523791e+00  3.111515e-01  8.045517e-01

# %% [markdown]
# # 2. Heatmap con seaborn
#
# Además del contenido recogido en la docu. teórica:
#
# https://seaborn.pydata.org/tutorial.html
#
# es aconsejable seguir este excelente (y práctico) tutorial:
#
# https://pythonbasics.org/seaborn-heatmap/

# %% [markdown]
# ## 2.1 Barplot por sexo y edad

# %%
#covid2 = covid.drop(['fecha', 'sexo'], axis = 1)

# %%
covid2 = covid.groupby(['provincia_iso', 
                        'grupo_edad']).sum(numeric_only = True)
covid2 = pd.DataFrame(covid2.to_records())

# %%
covid2.head()
# Out:
#   provincia_iso grupo_edad  num_casos  num_hosp  num_uci  num_def
# 0             A        0-9      45056       280        6        0
# 1             A      10-19      65367       240        6        1
# 2             A      20-29      65316       531       11        3
# 3             A      30-39      72331       992       52       10
# 4             A      40-49      86892      1788      171       58

# %%
covid2_hosp = covid2[['provincia_iso',
                      'grupo_edad',
                      'num_hosp']]

# %%
covid2_hosp.head()
# Out:
#   provincia_iso grupo_edad  num_hosp
# 0             A        0-9       280
# 1             A      10-19       240
# 2             A      20-29       531
# 3             A      30-39       992
# 4             A      40-49      1788

# %%
covid2_hosp = covid2_hosp.pivot(index = "provincia_iso", 
                                columns = "grupo_edad", 
                                values = "num_hosp")

# %%
covid2_hosp
# Out:
# grupo_edad      0-9  10-19  20-29  30-39  40-49  50-59  60-69  70-79    80+  \
# provincia_iso
# A               280    240    531    992   1788   2752   3617   3934   4782
# AB               78     62    148    254    426    741    921   1008   1565
# AL              109     63    281    492    706    906   1055    964    980
# AV               15     20     37     75    135    261    345    417    849
# B               220    254   1079   2354   4644   6795   8365   9600  13366
# BA               54     37    106    215    388    635    827   1054   1749
# BI               74     65    317    770   1600   2478   2692   2642   4008
# BU               27     38    151    272    477    775    981   1011   2009
# C                78    105    298    517    903   1212   1727   2076   2735
# CA               75     93    230    446    715   1107   1507   1619   1798
# CC               28     16     40     94    201    410    557    612   1469
# CE                4     19     33     50     60     93    135     92     76
# CO              108     95    246    425    609   1083   1249   1252   1861
# CR              127     79    176    347    535   1014   1377   1607   2610
# CS               82     82    163    365    611    876   1068   1099   1490
# CU               38     30    111    227    296    576    668    691   1410
# GC               69     41    178    349    533    766   1011    933    997
# GI               21     30     60    138    203    391    531    604    773
# GR              132    112    398    713   1157   1759   2094   2072   2527
# GU               34     37    104    195    322    525    553    613   1206
# H                82     56    174    298    467    624    767    703    713
# HU               38     28     71    116    196    327    433    509   1026
# J                85     53    194    329    592   1024   1221   1112   1704
# L                 8     10     29     54    124    192    248    314    527
# LE               28     36    133    238    385    681    960   1206   2776
# LO               32     36    115    235    435    631    774    879   1475
# LU               26     38     84    134    143    232    336    477    870
# M              1449   1208   4077   8543  14790  20383  22413  23029  31549
# MA              187    168    586   1040   1580   2005   2554   2563   2606
# ML               23     13     76    127    127    184    203    145    181
# MU              203    138    511   1038   1704   2336   2580   2410   3458
# NC               60     57    115    151    221    296    351    355    384
# O                70     82    244    487    997   1491   2194   2397   4427
# OR               27     46     87    151    205    337    491    746   1502
# P                21     35     76    121    215    340    487    582   1041
# PM               45     58    202    491   1018   1238   1523   1497   1983
# PO              112     85    218    434    649    896   1168   1386   2211
# S               114     82    194    432    642    826   1007   1043   1825
# SA               27     30     95    185    322    554    752    911   1818
# SE              215    160    475    954   1778   2611   2908   3134   3363
# SG               12     21     41     79    155    287    376    407    784
# SO               10      4     29     46    131    192    262    258    550
# SS               29     28     97    266    562    935   1185   1366   1778
# T                37     23     57    127    244    417    573    696    976
# TE               16     18     52     95    116    240    322    331    756
# TF               68     47    222    386    608    834   1016   1083   1437
# TO              117    129    355    633   1154   1711   2148   2387   4435
# V               726    519   1232   2012   3257   4134   4711   5052   7011
# VA               56     60    236    416    765   1226   1484   1765   2702
# VI               44     31     64    160    328    489    631    826   1037
# Z               219    132    431    818   1347   1994   2378   2611   4554
# ZA               17     19     47     98    146    306    430    473   1008
#
# grupo_edad       NC
# provincia_iso
# A                 1
# AB                0
# AL                0
# AV                0
# B                 0
# BA                9
# BI                0
# BU                0
# C                 0
# CA                2
# CC                0
# CE                0
# CO                0
# CR                0
# CS                0
# CU                0
# GC                0
# GI                0
# GR                0
# GU                0
# H                 0
# HU               15
# J                 0
# L                 0
# LE                0
# LO                3
# LU                0
# M                 2
# MA                2
# ML                0
# MU                3
# NC             1360
# O                 1
# OR                0
# P                 0
# PM                0
# PO                0
# S                 0
# SA                1
# SE                0
# SG                0
# SO                0
# SS                0
# T                 0
# TE               13
# TF                0
# TO                2
# V                 1
# VA                1
# VI                0
# Z               168
# ZA                1

# %%
ax = sns.heatmap(covid2_hosp)

# %%
fig, ax = plt.subplots(figsize=(15,15))         # Sample figsize in inches
ax = sns.heatmap(covid2_hosp)

# %%
fig, ax = plt.subplots(figsize=(15,15))         # Sample figsize in inches
paleta2 = sns.color_palette("rocket_r", as_cmap=True)
ax = sns.heatmap(covid2_hosp,
                 cmap = paleta2, 
                 annot = True,
                 fmt = "g")

# %%
fig, ax = plt.subplots(figsize=(15,15))         # Sample figsize in inches
diverging_colors = sns.color_palette("PiYG_r", 20)
ax = sns.heatmap(covid2_hosp,
                 cmap = diverging_colors)

# %%
fig, ax = plt.subplots(figsize=(15,15))         # Sample figsize in inches
mypalette = sns.color_palette("YlOrBr", as_cmap=True)
ax = sns.heatmap(covid2_hosp,
                 cmap = mypalette, 
                 annot = True, 
                fmt = "g" )

# %%
covid2_def = covid2[['provincia_iso',
                      'grupo_edad',
                      'num_def']]

# %%
fig, ax = plt.subplots(figsize=(15,15))         # Sample figsize in inches
covid2_def = covid2_def.pivot(index = "provincia_iso", 
                              columns = "grupo_edad", 
                              values = "num_def")
ax = sns.heatmap(covid2_def,
                cmap = mypalette,
                annot = True,
                fmt = "g")
